# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import matthews_corrcoef
from xgboost import XGBClassifier

# %%
pd.set_option("display.max_columns",100)
pd.set_option("display.max_rows",1000)
pd.options.display.max_seq_items = 2000

# %%
df_submission = pd.read_csv('sample_submission.csv')
data_track = pd.read_csv('test_player_tracking.csv')

# %%
data_track = data_track.drop(['game_key','play_id','datetime'],axis=1)

# %%
df_submission.head()
# Out:
#                    contact_id  contact
# 0  58168_003392_0_38590_43854        0
# 1  58168_003392_0_38590_41257        0
# 2  58168_003392_0_38590_41944        0
# 3  58168_003392_0_38590_42386        0
# 4  58168_003392_0_38590_47944        0

# %%
# df_submission['game_key'] = df_submission.contact_id.str.split("_", expand=True)[0]

# %%
# df_submission['play_id'] = df_submission.contact_id.str.split("_", expand=True)[1]

# %%
df_submission['game_play'] = df_submission.contact_id.str.split("_", expand=True)[0] \
                             + '_' \
                             + df_submission.contact_id.str.split("_", expand=True)[1]

# %%
df_submission['step'] = df_submission.contact_id.str.split("_", expand=True)[2]

# %%
df_submission['nfl_player_id_1'] = df_submission.contact_id.str.split("_", expand=True)[3]

# %%
df_submission['nfl_player_id_2'] = df_submission.contact_id.str.split("_", expand=True)[4]

# %%
df_submission.head()
# Out:
#                    contact_id  contact     game_play step nfl_player_id_1  \
# 0  58168_003392_0_38590_43854        0  58168_003392    0           38590
# 1  58168_003392_0_38590_41257        0  58168_003392    0           38590
# 2  58168_003392_0_38590_41944        0  58168_003392    0           38590
# 3  58168_003392_0_38590_42386        0  58168_003392    0           38590
# 4  58168_003392_0_38590_47944        0  58168_003392    0           38590
#
#   nfl_player_id_2
# 0           43854
# 1           41257
# 2           41944
# 3           42386
# 4           47944

# %% [markdown]
# ### Data Merging

# %%
data_track.dtypes
# Out:
# game_play         object
# nfl_player_id      int64
# step               int64
# team              object
# position          object
# jersey_number      int64
# x_position       float64
# y_position       float64
# speed            float64
# distance         float64
# direction        float64
# orientation      float64
# acceleration     float64
# sa               float64
# dtype: object

# %%
data_track['nfl_player_id'] = data_track['nfl_player_id'].astype('str')
# data_track['game_key'] = data_track['game_key'].astype('str')
# data_track['play_id'] = data_track['play_id'].astype('str')
data_track['step'] = data_track['step'].astype('str')

# %%
data_track.dtypes
# Out:
# game_play         object
# nfl_player_id     object
# step              object
# team              object
# position          object
# jersey_number      int64
# x_position       float64
# y_position       float64
# speed            float64
# distance         float64
# direction        float64
# orientation      float64
# acceleration     float64
# sa               float64
# dtype: object

# %%
df_submission.dtypes
# Out:
# contact_id         object
# contact             int64
# game_play          object
# step               object
# nfl_player_id_1    object
# nfl_player_id_2    object
# dtype: object

# %%
df_submission['nfl_player_id_1'] = df_submission['nfl_player_id_1'].astype('str')
df_submission['nfl_player_id_2'] = df_submission['nfl_player_id_2'].astype('str')
# df_submission['game_key'] = df_submission['game_key'].astype('str')
# df_submission['play_id'] = df_submission['play_id'].astype('str')
df_submission['step'] = df_submission['step'].astype('str')

# %%
df_submission.dtypes
# Out:
# contact_id         object
# contact             int64
# game_play          object
# step               object
# nfl_player_id_1    object
# nfl_player_id_2    object
# dtype: object

# %%
df_submission.shape
# Out:
# (49588, 6)

# %%
data_train = df_submission.merge(data_track, left_on = ['game_play', 'nfl_player_id_1', 'step'], \
                 right_on = ['game_play', 'nfl_player_id', 'step'], how ='left',suffixes=[None,'_id_1'])

# %%
data_train.head()
# Out:
#                    contact_id  contact     game_play step nfl_player_id_1  \
# 0  58168_003392_0_38590_43854        0  58168_003392    0           38590
# 1  58168_003392_0_38590_41257        0  58168_003392    0           38590
# 2  58168_003392_0_38590_41944        0  58168_003392    0           38590
# 3  58168_003392_0_38590_42386        0  58168_003392    0           38590
# 4  58168_003392_0_38590_47944        0  58168_003392    0           38590
#
#   nfl_player_id_2 nfl_player_id  team position  jersey_number  x_position  \
# 0           43854         38590  home        G             70       40.33
# 1           41257         38590  home        G             70       40.33
# 2           41944         38590  home        G             70       40.33
# 3           42386         38590  home        G             70       40.33
# 4           47944         38590  home        G             70       40.33
#
#    y_position  speed  distance  direction  orientation  acceleration    sa
# 0       25.28   0.52      0.06     141.08       100.37          0.59  0.58
# 1       25.28   0.52      0.06     141.08       100.37          0.59  0.58
# 2       25.28   0.52      0.06     141.08       100.37          0.59  0.58
# 3       25.28   0.52      0.06     141.08       100.37          0.59  0.58
# 4       25.28   0.52      0.06     141.08       100.37          0.59  0.58

# %%
data_train.shape
# Out:
# (49588, 18)

# %%
data_train.isna().sum()
# Out:
# contact_id         0
# contact            0
# game_play          0
# step               0
# nfl_player_id_1    0
# nfl_player_id_2    0
# nfl_player_id      0
# team               0
# position           0
# jersey_number      0
# x_position         0
# y_position         0
# speed              0
# distance           0
# direction          0
# orientation        0
# acceleration       0
# sa                 0
# dtype: int64

# %%
data_train = data_train.merge(data_track, left_on = ['game_play', 'nfl_player_id_2','step'], \
                 right_on = ['game_play', 'nfl_player_id', 'step'], how ='left',suffixes=['_id_1','_id_2'])

# %%
data_train.isna().sum()
# Out:
# contact_id               0
# contact                  0
# game_play                0
# step                     0
# nfl_player_id_1          0
# nfl_player_id_2          0
# nfl_player_id_id_1       0
# team_id_1                0
# position_id_1            0
# jersey_number_id_1       0
# x_position_id_1          0
# y_position_id_1          0
# speed_id_1               0
# distance_id_1            0
# direction_id_1           0
# orientation_id_1         0
# acceleration_id_1        0
# sa_id_1                  0
# nfl_player_id_id_2    4312
# team_id_2             4312
# position_id_2         4312
# jersey_number_id_2    4312
# x_position_id_2       4312
# y_position_id_2       4312
# speed_id_2            4312
# distance_id_2         4312
# direction_id_2        4312
# orientation_id_2      4312
# acceleration_id_2     4312
# sa_id_2               4312
# dtype: int64

# %%
data_train.head()
# Out:
#                    contact_id  contact     game_play step nfl_player_id_1  \
# 0  58168_003392_0_38590_43854        0  58168_003392    0           38590
# 1  58168_003392_0_38590_41257        0  58168_003392    0           38590
# 2  58168_003392_0_38590_41944        0  58168_003392    0           38590
# 3  58168_003392_0_38590_42386        0  58168_003392    0           38590
# 4  58168_003392_0_38590_47944        0  58168_003392    0           38590
#
#   nfl_player_id_2 nfl_player_id_id_1 team_id_1 position_id_1  \
# 0           43854              38590      home             G
# 1           41257              38590      home             G
# 2           41944              38590      home             G
# 3           42386              38590      home             G
# 4           47944              38590      home             G
#
#    jersey_number_id_1  x_position_id_1  y_position_id_1  speed_id_1  \
# 0                  70            40.33            25.28        0.52
# 1                  70            40.33            25.28        0.52
# 2                  70            40.33            25.28        0.52
# 3                  70            40.33            25.28        0.52
# 4                  70            40.33            25.28        0.52
#
#    distance_id_1  direction_id_1  orientation_id_1  acceleration_id_1  \
# 0           0.06          141.08            100.37               0.59
# 1           0.06          141.08            100.37               0.59
# 2           0.06          141.08            100.37               0.59
# 3           0.06          141.08            100.37               0.59
# 4           0.06          141.08            100.37               0.59
#
#    sa_id_1 nfl_player_id_id_2 team_id_2 position_id_2  jersey_number_id_2  \
# 0     0.58              43854      away           OLB                57.0
# 1     0.58              41257      away            CB                21.0
# 2     0.58              41944      away            DT                92.0
# 3     0.58              42386      away           ILB                55.0
# 4     0.58              47944      away            DE                94.0
#
#    x_position_id_2  y_position_id_2  speed_id_2  distance_id_2  \
# 0            41.99            16.79        0.74           0.06
# 1            45.77            15.59        0.67           0.07
# 2            42.00            22.85        0.68           0.08
# 3            45.87            23.89        0.61           0.06
# 4            42.10            26.58        0.20           0.03
#
#    direction_id_2  orientation_id_2  acceleration_id_2  sa_id_2
# 0          263.92            294.74               1.74     1.74
# 1          180.38            270.88               0.34     0.08
# 2          234.17            282.07               0.81     0.81
# 3          221.19            269.45               1.11     1.10
# 4          240.11            266.04               1.63     1.23

# %%
data_train = data_train.drop(['nfl_player_id_id_1','nfl_player_id_id_2'],axis=1)

# %% [markdown]
# ### Feature Engineering

# %%
data_track_eng = data_track[['game_play', 'nfl_player_id', 'step'
                            ,'x_position', 'y_position', 'speed', 'distance', 'direction', 'orientation'
                            ,'acceleration', 'sa']]

# %%
data_track_eng = data_track_eng.sort_values(['game_play', 'nfl_player_id', 'step'])

# %%
features = ['x_position', 'y_position', 'speed', 'distance', 'direction',\
                  'orientation', 'acceleration', 'sa']

features_lag1 = ['x_position_lag1', 'y_position_lag1', 'speed_lag1',\
                'distance_lag1', 'direction_lag1', 'orientation_lag1',\
                'acceleration_lag1', 'sa_lag1']

features_lag2 = ['x_position_lag2', 'y_position_lag2', 'speed_lag2',\
                'distance_lag2', 'direction_lag2', 'orientation_lag2',\
                'acceleration_lag2', 'sa_lag2']

# %%
data_track_eng[features_lag1] = \
                data_track_eng.groupby(['game_play', 'nfl_player_id'])\
                [features].shift(1)

# %%
data_track_eng[features_lag2] = \
                data_track_eng.groupby(['game_play', 'nfl_player_id'])\
                [features].shift(2)

# %%
feats_diff_within = ['speed','distance', 'direction', 'orientation', 'acceleration', 'sa']

for feats in feats_diff_within:
    data_track_eng[feats + '_diff_w' + '_lag1' + '_lag2'] = data_track_eng[feats+'_lag1'] - data_track_eng[feats+'_lag2']
    data_track_eng[feats + '_diff_w' + '_lag1'] = data_track_eng[feats] - data_track_eng[feats+'_lag1']

# %%
# columns to keep

keys = ['game_play', 'nfl_player_id', 'step']

feats_diff_w_cols = [col + '_diff_w' + '_lag1' + '_lag2' for col in feats_diff_within] + \
                    [col + '_diff_w' + '_lag1' for col in feats_diff_within]

feats_lag = ['x_position_lag1', 'y_position_lag1', 'x_position_lag2', 'y_position_lag2']

all_cols = keys + feats_diff_w_cols + feats_lag

data_track_eng[all_cols]
# Out:
#           game_play nfl_player_id  step  speed_diff_w_lag1_lag2  \
# 12815  58168_003392         37084    -1                     NaN
# 12624  58168_003392         37084   -10                     NaN
# 10637  58168_003392         37084  -100                   -0.16
# 10613  58168_003392         37084  -101                    0.33
# 10593  58168_003392         37084  -102                   -0.07
# ...             ...           ...   ...                     ...
# 8086   58172_003247         52939    95                    0.06
# 8103   58172_003247         52939    96                   -0.01
# 8137   58172_003247         52939    97                    0.03
# 8146   58172_003247         52939    98                   -0.04
# 8180   58172_003247         52939    99                    0.02
#
#        distance_diff_w_lag1_lag2  direction_diff_w_lag1_lag2  \
# 12815                        NaN                         NaN
# 12624                        NaN                         NaN
# 10637                      -0.02                      -39.17
# 10613                       0.04                       63.94
# 10593                      -0.01                      -13.76
# ...                          ...                         ...
# 8086                        0.01                       -1.53
# 8103                        0.00                       -1.30
# 8137                        0.00                       -0.32
# 8146                        0.00                       -0.61
# 8180                        0.00                       -0.99
#
#        orientation_diff_w_lag1_lag2  acceleration_diff_w_lag1_lag2  \
# 12815                           NaN                            NaN
# 12624                           NaN                            NaN
# 10637                          6.59                          -0.68
# 10613                        -10.75                           0.47
# 10593                          0.00                          -0.07
# ...                             ...                            ...
# 8086                           4.54                          -0.41
# 8103                          -0.90                          -0.28
# 8137                           0.00                          -0.38
# 8146                           0.00                          -0.03
# 8180                           1.89                          -0.06
#
#        sa_diff_w_lag1_lag2  speed_diff_w_lag1  distance_diff_w_lag1  \
# 12815                  NaN                NaN                   NaN
# 12624                  NaN              -0.16                 -0.02
# 10637                -0.66               0.33                  0.04
# 10613                 0.06              -0.07                 -0.01
# 10593                -0.20              -0.01                 -0.01
# ...                    ...                ...                   ...
# 8086                 -0.07              -0.01                  0.00
# 8103                 -0.21               0.03                  0.00
# 8137                 -0.09              -0.04                  0.00
# 8146                 -0.20               0.02                  0.00
# 8180                  0.05              -0.01                  0.00
#
#        direction_diff_w_lag1  orientation_diff_w_lag1  \
# 12815                    NaN                      NaN
# 12624                 -39.17                     6.59
# 10637                  63.94                   -10.75
# 10613                 -13.76                     0.00
# 10593                  -4.79                     1.64
# ...                      ...                      ...
# 8086                   -1.30                    -0.90
# 8103                   -0.32                     0.00
# 8137                   -0.61                     0.00
# 8146                   -0.99                     1.89
# 8180                   -0.57                     1.29
#
#        acceleration_diff_w_lag1  sa_diff_w_lag1  x_position_lag1  \
# 12815                       NaN             NaN              NaN
# 12624                     -0.68           -0.66            41.96
# 10637                      0.47            0.06            42.01
# 10613                     -0.07           -0.20            43.12
# 10593                      0.08           -0.02            43.18
# ...                         ...             ...              ...
# 8086                      -0.28           -0.21            45.69
# 8103                      -0.38           -0.09            45.37
# 8137                      -0.03           -0.20            45.04
# 8146                      -0.06            0.05            44.73
# 8180                       0.02           -0.08            44.43
#
#        y_position_lag1  x_position_lag2  y_position_lag2
# 12815              NaN              NaN              NaN
# 12624            20.10              NaN              NaN
# 10637            20.22            41.96            20.10
# 10613            20.05            42.01            20.22
# 10593            20.05            43.12            20.05
# ...                ...              ...              ...
# 8086             16.49            46.03            17.02
# 8103             15.96            45.69            16.49
# 8137             15.41            45.37            15.96
# 8146             14.87            45.04            15.41
# 8180             14.31            44.73            14.87
#
# [14872 rows x 19 columns]

# %%
# merging for player 1

feats_cols_id_1 = feats_diff_w_cols + feats_lag

feats_cols_id_1 = [feats + '_id_1' for feats in feats_cols_id_1]

new_cols_name = keys + feats_cols_id_1

data_track_eng_id_1 = data_track_eng[all_cols]

data_track_eng_id_1.columns = new_cols_name

data_track_eng_id_1.head()
# Out:
#           game_play nfl_player_id  step  speed_diff_w_lag1_lag2_id_1  \
# 12815  58168_003392         37084    -1                          NaN
# 12624  58168_003392         37084   -10                          NaN
# 10637  58168_003392         37084  -100                        -0.16
# 10613  58168_003392         37084  -101                         0.33
# 10593  58168_003392         37084  -102                        -0.07
#
#        distance_diff_w_lag1_lag2_id_1  direction_diff_w_lag1_lag2_id_1  \
# 12815                             NaN                              NaN
# 12624                             NaN                              NaN
# 10637                           -0.02                           -39.17
# 10613                            0.04                            63.94
# 10593                           -0.01                           -13.76
#
#        orientation_diff_w_lag1_lag2_id_1  acceleration_diff_w_lag1_lag2_id_1  \
# 12815                                NaN                                 NaN
# 12624                                NaN                                 NaN
# 10637                               6.59                               -0.68
# 10613                             -10.75                                0.47
# 10593                               0.00                               -0.07
#
#        sa_diff_w_lag1_lag2_id_1  speed_diff_w_lag1_id_1  \
# 12815                       NaN                     NaN
# 12624                       NaN                   -0.16
# 10637                     -0.66                    0.33
# 10613                      0.06                   -0.07
# 10593                     -0.20                   -0.01
#
#        distance_diff_w_lag1_id_1  direction_diff_w_lag1_id_1  \
# 12815                        NaN                         NaN
# 12624                      -0.02                      -39.17
# 10637                       0.04                       63.94
# 10613                      -0.01                      -13.76
# 10593                      -0.01                       -4.79
#
#        orientation_diff_w_lag1_id_1  acceleration_diff_w_lag1_id_1  \
# 12815                           NaN                            NaN
# 12624                          6.59                          -0.68
# 10637                        -10.75                           0.47
# 10613                          0.00                          -0.07
# 10593                          1.64                           0.08
#
#        sa_diff_w_lag1_id_1  x_position_lag1_id_1  y_position_lag1_id_1  \
# 12815                  NaN                   NaN                   NaN
# 12624                -0.66                 41.96                 20.10
# 10637                 0.06                 42.01                 20.22
# 10613                -0.20                 43.12                 20.05
# 10593                -0.02                 43.18                 20.05
#
#        x_position_lag2_id_1  y_position_lag2_id_1
# 12815                   NaN                   NaN
# 12624                   NaN                   NaN
# 10637                 41.96                 20.10
# 10613                 42.01                 20.22
# 10593                 43.12                 20.05

# %%
# merging for player 2

feats_cols_id_2 = feats_diff_w_cols + feats_lag

feats_cols_id_2 = [feats + '_id_2' for feats in feats_cols_id_2]

new_cols_name = keys + feats_cols_id_2

data_track_eng_id_2 = data_track_eng[all_cols]

data_track_eng_id_2.columns = new_cols_name

data_track_eng_id_2.head()
# Out:
#           game_play nfl_player_id  step  speed_diff_w_lag1_lag2_id_2  \
# 12815  58168_003392         37084    -1                          NaN
# 12624  58168_003392         37084   -10                          NaN
# 10637  58168_003392         37084  -100                        -0.16
# 10613  58168_003392         37084  -101                         0.33
# 10593  58168_003392         37084  -102                        -0.07
#
#        distance_diff_w_lag1_lag2_id_2  direction_diff_w_lag1_lag2_id_2  \
# 12815                             NaN                              NaN
# 12624                             NaN                              NaN
# 10637                           -0.02                           -39.17
# 10613                            0.04                            63.94
# 10593                           -0.01                           -13.76
#
#        orientation_diff_w_lag1_lag2_id_2  acceleration_diff_w_lag1_lag2_id_2  \
# 12815                                NaN                                 NaN
# 12624                                NaN                                 NaN
# 10637                               6.59                               -0.68
# 10613                             -10.75                                0.47
# 10593                               0.00                               -0.07
#
#        sa_diff_w_lag1_lag2_id_2  speed_diff_w_lag1_id_2  \
# 12815                       NaN                     NaN
# 12624                       NaN                   -0.16
# 10637                     -0.66                    0.33
# 10613                      0.06                   -0.07
# 10593                     -0.20                   -0.01
#
#        distance_diff_w_lag1_id_2  direction_diff_w_lag1_id_2  \
# 12815                        NaN                         NaN
# 12624                      -0.02                      -39.17
# 10637                       0.04                       63.94
# 10613                      -0.01                      -13.76
# 10593                      -0.01                       -4.79
#
#        orientation_diff_w_lag1_id_2  acceleration_diff_w_lag1_id_2  \
# 12815                           NaN                            NaN
# 12624                          6.59                          -0.68
# 10637                        -10.75                           0.47
# 10613                          0.00                          -0.07
# 10593                          1.64                           0.08
#
#        sa_diff_w_lag1_id_2  x_position_lag1_id_2  y_position_lag1_id_2  \
# 12815                  NaN                   NaN                   NaN
# 12624                -0.66                 41.96                 20.10
# 10637                 0.06                 42.01                 20.22
# 10613                -0.20                 43.12                 20.05
# 10593                -0.02                 43.18                 20.05
#
#        x_position_lag2_id_2  y_position_lag2_id_2
# 12815                   NaN                   NaN
# 12624                   NaN                   NaN
# 10637                 41.96                 20.10
# 10613                 42.01                 20.22
# 10593                 43.12                 20.05

# %%
data_train = data_train.merge(data_track_eng_id_1, left_on=['game_play', 'nfl_player_id_1', 'step']\
                 , right_on=keys, how='left')

# %%
data_train = data_train.merge(data_track_eng_id_2, left_on=['game_play', 'nfl_player_id_2', 'step']\
                 , right_on=keys, how='left')

# %%
def Euclidean_Dist(df, cols_1=['x_coord','y_coord'], cols_2=['x_coord','y_coord']):
    return np.linalg.norm(df[cols_1].values - df[cols_2].values,
                   axis=1)

# %%
data_train['dist_lag2'] =  Euclidean_Dist(data_train, cols_1=['x_position_lag2_id_1','y_position_lag2_id_1'], \
               cols_2=['x_position_lag2_id_2','y_position_lag2_id_2'])

# %%
data_train['dist_lag1'] =  Euclidean_Dist(data_train, cols_1=['x_position_lag1_id_1','y_position_lag1_id_1'], \
               cols_2=['x_position_lag1_id_2','y_position_lag1_id_2'])

# %%
data_train['dist'] =  Euclidean_Dist(data_train, cols_1=['x_position_id_1','y_position_id_1'], \
               cols_2=['x_position_id_2','y_position_id_2'])

# %%
data_train['dist_lag1_lag2'] = data_train['dist_lag1'] - data_train['dist_lag2']

# %%
data_train['dist_current_lag1'] = data_train['dist'] - data_train['dist_lag1']

# %% [markdown]
# ### P-P Predictions

# %%
data_train_pp = data_train[data_train.nfl_player_id_2 !='G']

# %%
target = ['contact']

features_current_id_1 = ['speed_id_1', 'distance_id_1', 'direction_id_1', 'orientation_id_1', 'acceleration_id_1', \
                         'sa_id_1']

features_current_id_2 = ['speed_id_2', 'distance_id_2', 'direction_id_2', 'orientation_id_2', 'acceleration_id_2', \
                         'sa_id_2']


features_lag_id_1 = ['speed_diff_w_lag1_lag2_id_1', 'distance_diff_w_lag1_lag2_id_1', 'direction_diff_w_lag1_lag2_id_1',\
                     'orientation_diff_w_lag1_lag2_id_1', 'acceleration_diff_w_lag1_lag2_id_1', \
                     'sa_diff_w_lag1_lag2_id_1', 'speed_diff_w_lag1_id_1', 'distance_diff_w_lag1_id_1', \
                     'direction_diff_w_lag1_id_1', 'orientation_diff_w_lag1_id_1', 'acceleration_diff_w_lag1_id_1', \
                     'sa_diff_w_lag1_id_1']

features_lag_id_2 = ['speed_diff_w_lag1_lag2_id_2', 'distance_diff_w_lag1_lag2_id_2', 'direction_diff_w_lag1_lag2_id_2',\
                     'orientation_diff_w_lag1_lag2_id_2', 'acceleration_diff_w_lag1_lag2_id_2', \
                     'sa_diff_w_lag1_lag2_id_2', 'speed_diff_w_lag1_id_2', 'distance_diff_w_lag1_id_2', \
                     'direction_diff_w_lag1_id_2', 'orientation_diff_w_lag1_id_2', 'acceleration_diff_w_lag1_id_2', \
                     'sa_diff_w_lag1_id_2']

features_dist = ['dist_lag2', 'dist_lag1', 'dist', 'dist_lag1_lag2', 'dist_current_lag1']

all_cols = features_current_id_1 + features_current_id_2 + features_lag_id_1 + features_lag_id_2 \
           + features_dist + target

# %%
#For Kaggle
# The predictions would be put in contact column in this data frame
data_train_pp.to_csv("train_with_contact_id.csv",index=False)

# %%
data_train_pp_m = data_train_pp[all_cols]

# %% [markdown]
# ### Load the training data

# %%
df_train_preprocessed = pd.read_csv('training_pp.csv')

# %% [markdown]
# ### Train XGB

# %%
X = df_train_preprocessed.drop('contact', axis=1)
y = df_train_preprocessed['contact']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred_xgb = model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# [[850622   2058]
#  [  3599   5918]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    852680
#            1       0.74      0.62      0.68      9517
#
#     accuracy                           0.99    862197
#    macro avg       0.87      0.81      0.84    862197
# weighted avg       0.99      0.99      0.99    862197

# %%
print(confusion_matrix(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# [[850622   2058]
#  [  3599   5918]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    852680
#            1       0.74      0.62      0.68      9517
#
#     accuracy                           0.99    862197
#    macro avg       0.87      0.81      0.84    862197
# weighted avg       0.99      0.99      0.99    862197

# %%
matthews_corrcoef(y_test, y_pred_xgb)
# Out:
# 0.67600722091378

# %% [markdown]
# ### Probability cutoff to be set at 0.35

# %%
probs = model.predict_proba(X_test)

# %%
y_pred_035 = np.where(probs >0.35, 1,0)[:,1]

# %%
matthews_corrcoef(y_test, y_pred_035)
# Out:
# 0.6978211155920463

# %% [markdown]
# ### Predicting on Data

# %% [markdown]
# #### Train on complete data

# %%
model_complete = XGBClassifier()
model_complete.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
data_predict = data_train_pp_m

# %%
data_predict.columns
# Out:
# Index(['speed_id_1', 'distance_id_1', 'direction_id_1', 'orientation_id_1',
#        'acceleration_id_1', 'sa_id_1', 'speed_id_2', 'distance_id_2',
#        'direction_id_2', 'orientation_id_2', 'acceleration_id_2', 'sa_id_2',
#        'speed_diff_w_lag1_lag2_id_1', 'distance_diff_w_lag1_lag2_id_1',
#        'direction_diff_w_lag1_lag2_id_1', 'orientation_diff_w_lag1_lag2_id_1',
#        'acceleration_diff_w_lag1_lag2_id_1', 'sa_diff_w_lag1_lag2_id_1',
#        'speed_diff_w_lag1_id_1', 'distance_diff_w_lag1_id_1',
#        'direction_diff_w_lag1_id_1', 'orientation_diff_w_lag1_id_1',
#        'acceleration_diff_w_lag1_id_1', 'sa_diff_w_lag1_id_1',
#        'speed_diff_w_lag1_lag2_id_2', 'distance_diff_w_lag1_lag2_id_2',
#        'direction_diff_w_lag1_lag2_id_2', 'orientation_diff_w_lag1_lag2_id_2',
#        'acceleration_diff_w_lag1_lag2_id_2', 'sa_diff_w_lag1_lag2_id_2',
#        'speed_diff_w_lag1_id_2', 'distance_diff_w_lag1_id_2',
#        'direction_diff_w_lag1_id_2', 'orientation_diff_w_lag1_id_2',
#        'acceleration_diff_w_lag1_id_2', 'sa_diff_w_lag1_id_2', 'dist_lag2',
#        'dist_lag1', 'dist', 'dist_lag1_lag2', 'dist_current_lag1', 'contact'],
#       dtype='object')

# %%
[True for x,y in zip(data_predict.drop('contact',axis =1).columns,data_predict.columns) if x==y]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
### Writing out data_predict for kaggle

data_predict.to_csv('data_predict.csv',index=False)
data_predict = pd.read_csv('data_predict.csv')

# %%
probs_predict = model_complete.predict_proba(data_predict.drop('contact',axis =1))

# %%
data_predict['contact'] = np.where(probs_predict >0.35, 1,0)[:,1]
# Out:
# /var/folders/z2/rdt7vxy91fz7f7gkqbtqbgk40000gn/T/ipykernel_20592/3861266841.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_predict['contact'] = np.where(probs_predict >0.35, 1,0)[:,1]

# %%
data_predict
# Out:
#        speed_id_1  distance_id_1  direction_id_1  orientation_id_1  \
# 0            0.52           0.06          141.08            100.37
# 1            0.52           0.06          141.08            100.37
# 2            0.52           0.06          141.08            100.37
# 3            0.52           0.06          141.08            100.37
# 4            0.52           0.06          141.08            100.37
# ...           ...            ...             ...               ...
# 49561        0.47           0.06          293.42             19.08
# 49562        0.47           0.06          293.42             19.08
# 49563        0.47           0.06          293.42             19.08
# 49564        0.47           0.06          293.42             19.08
# 49565        0.47           0.06          293.42             19.08
#
#        acceleration_id_1  sa_id_1  speed_id_2  distance_id_2  direction_id_2  \
# 0                   0.59     0.58        0.74           0.06          263.92
# 1                   0.59     0.58        0.67           0.07          180.38
# 2                   0.59     0.58        0.68           0.08          234.17
# 3                   0.59     0.58        0.61           0.06          221.19
# 4                   0.59     0.58        0.20           0.03          240.11
# ...                  ...      ...         ...            ...             ...
# 49561               1.02     0.74        0.79           0.08          148.92
# 49562               1.02     0.74        0.54           0.05          136.05
# 49563               1.02     0.74        4.72           0.48          247.51
# 49564               1.02     0.74        1.41           0.15          163.22
# 49565               1.02     0.74        2.29           0.24          211.73
#
#        orientation_id_2  acceleration_id_2  sa_id_2  \
# 0                294.74               1.74     1.74
# 1                270.88               0.34     0.08
# 2                282.07               0.81     0.81
# 3                269.45               1.11     1.10
# 4                266.04               1.63     1.23
# ...                 ...                ...      ...
# 49561            130.02               1.40    -0.06
# 49562            183.46               0.75    -0.47
# 49563            255.55               1.34    -1.08
# 49564            185.42               0.75    -0.58
# 49565            215.11               2.43    -2.43
#
#        speed_diff_w_lag1_lag2_id_1  distance_diff_w_lag1_lag2_id_1  \
# 0                             0.06                            0.01
# 1                             0.06                            0.01
# 2                             0.06                            0.01
# 3                             0.06                            0.01
# 4                             0.06                            0.01
# ...                            ...                             ...
# 49561                         0.01                           -0.01
# 49562                         0.01                           -0.01
# 49563                         0.01                           -0.01
# 49564                         0.01                           -0.01
# 49565                         0.01                           -0.01
#
#        direction_diff_w_lag1_lag2_id_1  orientation_diff_w_lag1_lag2_id_1  \
# 0                                 3.16                               0.00
# 1                                 3.16                               0.00
# 2                                 3.16                               0.00
# 3                                 3.16                               0.00
# 4                                 3.16                               0.00
# ...                                ...                                ...
# 49561                           -10.05                               1.02
# 49562                           -10.05                               1.02
# 49563                           -10.05                               1.02
# 49564                           -10.05                               1.02
# 49565                           -10.05                               1.02
#
#        acceleration_diff_w_lag1_lag2_id_1  sa_diff_w_lag1_lag2_id_1  \
# 0                                    0.17                     -0.16
# 1                                    0.17                     -0.16
# 2                                    0.17                     -0.16
# 3                                    0.17                     -0.16
# 4                                    0.17                     -0.16
# ...                                   ...                       ...
# 49561                               -0.02                      0.14
# 49562                               -0.02                      0.14
# 49563                               -0.02                      0.14
# 49564                               -0.02                      0.14
# 49565                               -0.02                      0.14
#
#        speed_diff_w_lag1_id_1  distance_diff_w_lag1_id_1  \
# 0                        0.09                       0.01
# 1                        0.09                       0.01
# 2                        0.09                       0.01
# 3                        0.09                       0.01
# 4                        0.09                       0.01
# ...                       ...                        ...
# 49561                    0.13                       0.03
# 49562                    0.13                       0.03
# 49563                    0.13                       0.03
# 49564                    0.13                       0.03
# 49565                    0.13                       0.03
#
#        direction_diff_w_lag1_id_1  orientation_diff_w_lag1_id_1  \
# 0                           81.07                         22.47
# 1                           81.07                         22.47
# 2                           81.07                         22.47
# 3                           81.07                         22.47
# 4                           81.07                         22.47
# ...                           ...                           ...
# 49561                      -32.27                         -2.14
# 49562                      -32.27                         -2.14
# 49563                      -32.27                         -2.14
# 49564                      -32.27                         -2.14
# 49565                      -32.27                         -2.14
#
#        acceleration_diff_w_lag1_id_1  sa_diff_w_lag1_id_1  \
# 0                              -0.23                 1.30
# 1                              -0.23                 1.30
# 2                              -0.23                 1.30
# 3                              -0.23                 1.30
# 4                              -0.23                 1.30
# ...                              ...                  ...
# 49561                           0.46                 0.59
# 49562                           0.46                 0.59
# 49563                           0.46                 0.59
# 49564                           0.46                 0.59
# 49565                           0.46                 0.59
#
#        speed_diff_w_lag1_lag2_id_2  distance_diff_w_lag1_lag2_id_2  \
# 0                            -0.09                           -0.01
# 1                             0.13                            0.02
# 2                            -0.03                           -0.01
# 3                            -0.05                            0.00
# 4                            -0.04                           -0.01
# ...                            ...                             ...
# 49561                        -0.11                           -0.01
# 49562                        -0.05                           -0.01
# 49563                        -0.08                           -0.01
# 49564                        -0.15                           -0.02
# 49565                        -0.28                           -0.02
#
#        direction_diff_w_lag1_lag2_id_2  orientation_diff_w_lag1_lag2_id_2  \
# 0                                13.12                               2.70
# 1                                 0.97                              -1.38
# 2                               -32.17                              -1.58
# 3                                 4.01                              -3.06
# 4                                -3.29                              -1.02
# ...                                ...                                ...
# 49561                           -19.42                               1.07
# 49562                            -6.27                               0.00
# 49563                             1.43                               1.92
# 49564                             6.18                               4.56
# 49565                            -0.05                               0.00
#
#        acceleration_diff_w_lag1_lag2_id_2  sa_diff_w_lag1_lag2_id_2  \
# 0                                   -0.13                     -0.23
# 1                                   -0.16                      0.16
# 2                                   -0.04                     -0.16
# 3                                    0.07                      0.10
# 4                                   -0.11                     -0.01
# ...                                   ...                       ...
# 49561                                0.60                      0.11
# 49562                               -0.10                     -0.19
# 49563                               -0.02                     -0.05
# 49564                                0.57                     -0.42
# 49565                                0.00                      0.00
#
#        speed_diff_w_lag1_id_2  distance_diff_w_lag1_id_2  \
# 0                        0.27                       0.02
# 1                       -0.47                      -0.05
# 2                        0.62                       0.07
# 3                        0.21                       0.02
# 4                       -0.87                      -0.08
# ...                       ...                        ...
# 49561                   -0.01                       0.00
# 49562                   -0.17                      -0.02
# 49563                   -0.06                       0.00
# 49564                    0.00                       0.01
# 49565                   -0.25                      -0.03
#
#        direction_diff_w_lag1_id_2  orientation_diff_w_lag1_id_2  \
# 0                           54.80                         13.36
# 1                          161.03                         26.01
# 2                          107.00                         -1.97
# 3                          208.74                        -11.72
# 4                          -89.15                        -41.51
# ...                           ...                           ...
# 49561                      -14.38                          0.81
# 49562                       -4.37                         -0.76
# 49563                        0.85                          3.09
# 49564                        0.05                          1.12
# 49565                       -0.66                          0.00
#
#        acceleration_diff_w_lag1_id_2  sa_diff_w_lag1_id_2  dist_lag2  \
# 0                               0.64                 1.08   8.171328
# 1                              -0.47                 0.88   6.871863
# 2                               0.68                 0.91   3.442005
# 3                               0.60                 0.61   6.121340
# 4                               1.45                 1.36   3.279893
# ...                              ...                  ...        ...
# 49561                           0.12                 0.36   6.453681
# 49562                           0.06                -0.48   5.677861
# 49563                          -0.12                 0.00  18.757809
# 49564                          -0.19                 0.20   6.418754
# 49565                          -0.11                 0.11  11.323431
#
#        dist_lag1       dist  dist_lag1_lag2  dist_current_lag1  contact
# 0       8.124340   8.650763       -0.046988           0.526423        0
# 1       6.861385  11.112592       -0.010478           4.251207        0
# 2       3.453143   2.948525        0.011138          -0.504618        0
# 3       6.166036   5.711716        0.044696          -0.454320        0
# 4       3.383622   2.196110        0.103729          -1.187512        0
# ...          ...        ...             ...                ...      ...
# 49561   6.491672   6.598257        0.037990           0.106586        0
# 49562   5.746529   5.846469        0.068669           0.099940        0
# 49563  18.279765  17.865369       -0.478044          -0.414396        0
# 49564   6.262755   6.083305       -0.155999          -0.179450        0
# 49565  11.129173  11.004336       -0.194258          -0.124838        0
#
# [45276 rows x 42 columns]

# %%
data_train_pp['contact']=np.where(probs_predict >0.35, 1,0)[:,1]
# Out:
# /var/folders/z2/rdt7vxy91fz7f7gkqbtqbgk40000gn/T/ipykernel_20592/4117240683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_pp['contact']=np.where(probs_predict >0.35, 1,0)[:,1]

# %%
data_train_pp.head()
# Out:
#                    contact_id  contact     game_play step nfl_player_id_1  \
# 0  58168_003392_0_38590_43854        0  58168_003392    0           38590
# 1  58168_003392_0_38590_41257        0  58168_003392    0           38590
# 2  58168_003392_0_38590_41944        0  58168_003392    0           38590
# 3  58168_003392_0_38590_42386        0  58168_003392    0           38590
# 4  58168_003392_0_38590_47944        0  58168_003392    0           38590
#
#   nfl_player_id_2 team_id_1 position_id_1  jersey_number_id_1  \
# 0           43854      home             G                  70
# 1           41257      home             G                  70
# 2           41944      home             G                  70
# 3           42386      home             G                  70
# 4           47944      home             G                  70
#
#    x_position_id_1  y_position_id_1  speed_id_1  distance_id_1  \
# 0            40.33            25.28        0.52           0.06
# 1            40.33            25.28        0.52           0.06
# 2            40.33            25.28        0.52           0.06
# 3            40.33            25.28        0.52           0.06
# 4            40.33            25.28        0.52           0.06
#
#    direction_id_1  orientation_id_1  acceleration_id_1  sa_id_1 team_id_2  \
# 0          141.08            100.37               0.59     0.58      away
# 1          141.08            100.37               0.59     0.58      away
# 2          141.08            100.37               0.59     0.58      away
# 3          141.08            100.37               0.59     0.58      away
# 4          141.08            100.37               0.59     0.58      away
#
#   position_id_2  jersey_number_id_2  x_position_id_2  y_position_id_2  \
# 0           OLB                57.0            41.99            16.79
# 1            CB                21.0            45.77            15.59
# 2            DT                92.0            42.00            22.85
# 3           ILB                55.0            45.87            23.89
# 4            DE                94.0            42.10            26.58
#
#    speed_id_2  distance_id_2  direction_id_2  orientation_id_2  \
# 0        0.74           0.06          263.92            294.74
# 1        0.67           0.07          180.38            270.88
# 2        0.68           0.08          234.17            282.07
# 3        0.61           0.06          221.19            269.45
# 4        0.20           0.03          240.11            266.04
#
#    acceleration_id_2  sa_id_2 nfl_player_id_x  speed_diff_w_lag1_lag2_id_1  \
# 0               1.74     1.74           38590                         0.06
# 1               0.34     0.08           38590                         0.06
# 2               0.81     0.81           38590                         0.06
# 3               1.11     1.10           38590                         0.06
# 4               1.63     1.23           38590                         0.06
#
#    distance_diff_w_lag1_lag2_id_1  direction_diff_w_lag1_lag2_id_1  \
# 0                            0.01                             3.16
# 1                            0.01                             3.16
# 2                            0.01                             3.16
# 3                            0.01                             3.16
# 4                            0.01                             3.16
#
#    orientation_diff_w_lag1_lag2_id_1  acceleration_diff_w_lag1_lag2_id_1  \
# 0                                0.0                                0.17
# 1                                0.0                                0.17
# 2                                0.0                                0.17
# 3                                0.0                                0.17
# 4                                0.0                                0.17
#
#    sa_diff_w_lag1_lag2_id_1  speed_diff_w_lag1_id_1  \
# 0                     -0.16                    0.09
# 1                     -0.16                    0.09
# 2                     -0.16                    0.09
# 3                     -0.16                    0.09
# 4                     -0.16                    0.09
#
#    distance_diff_w_lag1_id_1  direction_diff_w_lag1_id_1  \
# 0                       0.01                       81.07
# 1                       0.01                       81.07
# 2                       0.01                       81.07
# 3                       0.01                       81.07
# 4                       0.01                       81.07
#
#    orientation_diff_w_lag1_id_1  acceleration_diff_w_lag1_id_1  \
# 0                         22.47                          -0.23
# 1                         22.47                          -0.23
# 2                         22.47                          -0.23
# 3                         22.47                          -0.23
# 4                         22.47                          -0.23
#
#    sa_diff_w_lag1_id_1  x_position_lag1_id_1  y_position_lag1_id_1  \
# 0                  1.3                 39.78                 25.15
# 1                  1.3                 39.78                 25.15
# 2                  1.3                 39.78                 25.15
# 3                  1.3                 39.78                 25.15
# 4                  1.3                 39.78                 25.15
#
#    x_position_lag2_id_1  y_position_lag2_id_1 nfl_player_id_y  \
# 0                 39.82                 25.17           43854
# 1                 39.82                 25.17           41257
# 2                 39.82                 25.17           41944
# 3                 39.82                 25.17           42386
# 4                 39.82                 25.17           47944
#
#    speed_diff_w_lag1_lag2_id_2  distance_diff_w_lag1_lag2_id_2  \
# 0                        -0.09                           -0.01
# 1                         0.13                            0.02
# 2                        -0.03                           -0.01
# 3                        -0.05                            0.00
# 4                        -0.04                           -0.01
#
#    direction_diff_w_lag1_lag2_id_2  orientation_diff_w_lag1_lag2_id_2  \
# 0                            13.12                               2.70
# 1                             0.97                              -1.38
# 2                           -32.17                              -1.58
# 3                             4.01                              -3.06
# 4                            -3.29                              -1.02
#
#    acceleration_diff_w_lag1_lag2_id_2  sa_diff_w_lag1_lag2_id_2  \
# 0                               -0.13                     -0.23
# 1                               -0.16                      0.16
# 2                               -0.04                     -0.16
# 3                                0.07                      0.10
# 4                               -0.11                     -0.01
#
#    speed_diff_w_lag1_id_2  distance_diff_w_lag1_id_2  \
# 0                    0.27                       0.02
# 1                   -0.47                      -0.05
# 2                    0.62                       0.07
# 3                    0.21                       0.02
# 4                   -0.87                      -0.08
#
#    direction_diff_w_lag1_id_2  orientation_diff_w_lag1_id_2  \
# 0                       54.80                         13.36
# 1                      161.03                         26.01
# 2                      107.00                         -1.97
# 3                      208.74                        -11.72
# 4                      -89.15                        -41.51
#
#    acceleration_diff_w_lag1_id_2  sa_diff_w_lag1_id_2  x_position_lag1_id_2  \
# 0                           0.64                 1.08                 42.43
# 1                          -0.47                 0.88                 46.43
# 2                           0.68                 0.91                 42.67
# 3                           0.60                 0.61                 45.20
# 4                           1.45                 1.36                 43.11
#
#    y_position_lag1_id_2  x_position_lag2_id_2  y_position_lag2_id_2  \
# 0                 17.47                 42.41                 17.42
# 1                 26.84                 46.46                 26.94
# 2                 23.26                 42.67                 23.24
# 3                 22.21                 45.20                 22.25
# 4                 24.55                 43.06                 24.66
#
#    dist_lag2  dist_lag1       dist  dist_lag1_lag2  dist_current_lag1
# 0   8.171328   8.124340   8.650763       -0.046988           0.526423
# 1   6.871863   6.861385  11.112592       -0.010478           4.251207
# 2   3.442005   3.453143   2.948525        0.011138          -0.504618
# 3   6.121340   6.166036   5.711716        0.044696          -0.454320
# 4   3.279893   3.383622   2.196110        0.103729          -1.187512

# %%
data_train_pp.contact.value_counts()
# Out:
# 0    44656
# 1      620
# Name: contact, dtype: int64

# %%
data_train_pp[['contact_id','contact']].to_csv('submissions.csv', index = False)
